# %%
# imports
from conllu import parse
import json
import pandas as pd

# %%
# read the CoNLL-U file
with open("fi_tdt-ud-train.conllu", "r", encoding="utf-8") as f:
    data = f.read()

# parse the CoNLL-U data
sentences = parse(data)

# initialize dictionary to store counts of different forms of verbs
feats_freqs = {}

# counting the amounts of different forms of verbs
for sentence in sentences: 
    for token in sentence:
        if token["upos"] == "VERB":
            feats_string = json.dumps(token["feats"])
            if feats_string not in feats_freqs:
                feats_freqs[feats_string] = [1, token["form"].lower()]
            else:
                feats_freqs[feats_string][0] += 1

print(f"There are only {len(feats_freqs)} different forms in all the verbs in this data set.")
# Out:
# There are only 408 different forms in all the verbs in this data set.

# %%
# display 20 most frequent verb forms
feats_freqs_df = pd.DataFrame.from_dict(feats_freqs, orient='index', columns=["Frequencies", "Example"])
feats_freqs_df = feats_freqs_df.sort_values(by="Frequencies", ascending=False)
feats_freqs_df.head(20)
# Out:
#                                                     Frequencies  \
# {"Mood": "Ind", "Number": "Sing", "Person": "3"...         2801
# {"Mood": "Ind", "Number": "Sing", "Person": "3"...         2517
# {"InfForm": "1", "Number": "Sing", "VerbForm": ...         2460
# {"Case": "Nom", "Number": "Sing", "PartForm": "...         1256
# {"Mood": "Ind", "Tense": "Pres", "VerbForm": "F...         1030
# {"Mood": "Ind", "Number": "Plur", "Person": "3"...          820
# {"Case": "Ill", "InfForm": "3", "Number": "Sing...          727
# {"Mood": "Ind", "Number": "Sing", "Person": "1"...          661
# {"Case": "Nom", "Number": "Sing", "PartForm": "...          648
# {"Connegative": "Yes", "Mood": "Ind", "Tense": ...          586
# {"Mood": "Ind", "Tense": "Past", "VerbForm": "F...          550
# {"Mood": "Ind", "Number": "Plur", "Person": "3"...          535
# {"Mood": "Ind", "Number": "Sing", "Person": "1"...          484
# {"Case": "Nom", "Number": "Sing", "PartForm": "...          317
# {"Case": "Gen", "Number": "Sing", "PartForm": "...          310
# {"Case": "Nom", "Number": "Plur", "PartForm": "...          280
# {"Case": "Nom", "Number": "Sing", "PartForm": "...          237
# {"Case": "Ins", "InfForm": "2", "Number": "Sing...          223
# {"Mood": "Imp", "Number": "Sing", "Person": "2"...          216
# {"Mood": "Ind", "Number": "Sing", "Person": "0"...          198
#
#                                                            Example
# {"Mood": "Ind", "Number": "Sing", "Person": "3"...             vei
# {"Mood": "Ind", "Number": "Sing", "Person": "3"...            avaa
# {"InfForm": "1", "Number": "Sing", "VerbForm": ...          katsoa
# {"Case": "Nom", "Number": "Sing", "PartForm": "...         noussut
# {"Mood": "Ind", "Tense": "Pres", "VerbForm": "F...     lavastetaan
# {"Mood": "Ind", "Number": "Plur", "Person": "3"...      hidastavat
# {"Case": "Ill", "InfForm": "3", "Number": "Sing...      kävelemään
# {"Mood": "Ind", "Number": "Sing", "Person": "1"...            näin
# {"Case": "Nom", "Number": "Sing", "PartForm": "...     restauroitu
# {"Connegative": "Yes", "Mood": "Ind", "Tense": ...            tule
# {"Mood": "Ind", "Tense": "Past", "VerbForm": "F...       etsittiin
# {"Mood": "Ind", "Number": "Plur", "Person": "3"...  uskaltautuivat
# {"Mood": "Ind", "Number": "Sing", "Person": "1"...           pidän
# {"Case": "Nom", "Number": "Sing", "PartForm": "...    kritisoitava
# {"Case": "Gen", "Number": "Sing", "PartForm": "...       täyttävän
# {"Case": "Nom", "Number": "Plur", "PartForm": "...        ottaneet
# {"Case": "Nom", "Number": "Sing", "PartForm": "...       lopettava
# {"Case": "Ins", "InfForm": "2", "Number": "Sing...          lukien
# {"Mood": "Imp", "Number": "Sing", "Person": "2"...           soita
# {"Mood": "Ind", "Number": "Sing", "Person": "0"...         päättää
